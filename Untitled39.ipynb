# %%
1. What is the Probability density function?

The probability density function (PDF) describes the likelihood of a continuous random variable taking a specific value. The area under the curve of the PDF represents the probability of the variable falling within a particular range.
Q2. What are the types of Probability distribution?

Discrete distributions: e.g., Binomial, Poisson, Geometric.
Continuous distributions: e.g., Normal, Exponential, Uniform, Beta.
Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

python
Copy
import math

def normal_pdf(x, mean, std_dev):
    return (1 / (std_dev * math.sqrt(2 * math.pi))) * math.exp(-0.5 * ((x - mean) / std_dev) ** 2)
Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

Properties:
Fixed number of trials.
Each trial has two outcomes (success or failure).
The probability of success is constant.
Trials are independent.
Examples:
Flipping a coin 10 times (success = heads).
Testing 20 light bulbs for defects (success = non-defective).
Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

python
Copy
import numpy as np
import matplotlib.pyplot as plt

data = np.random.binomial(1, 0.4, 1000)
plt.hist(data, bins=2, edgecolor='black')
plt.show()
Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

python
Copy
from scipy.stats import poisson

def poisson_cdf(k, mean):
    return poisson.cdf(k, mean)
Q7. How Binomial distribution different from Poisson distribution?

Binomial: Deals with a fixed number of trials, with two outcomes, and a fixed probability of success.
Poisson: Deals with the number of events occurring in a fixed interval of time or space, with a known average rate, and events happen independently.
Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

python
Copy
data = np.random.poisson(5, 1000)
mean = np.mean(data)
variance = np.var(data)
Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

Binomial distribution: Mean = 
𝑛
⋅
𝑝
n⋅p, Variance = 
𝑛
⋅
𝑝
⋅
(
1
−
𝑝
)
n⋅p⋅(1−p).
Poisson distribution: Mean = Variance = λ (where λ is the rate parameter).
Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

In a normal distribution, the least frequent data appears at the extremes (far from the mean), towards both the left and right tails of the distribution.
